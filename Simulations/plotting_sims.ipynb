# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_ecdf(data):
    # Step 2: Sort the data
    data_sorted = np.sort(data)

    # Step 3: Calculate the empirical CDF
    # For each point, the CDF value is the proportion of data points less than or equal to that point
    cdf_values = np.arange(1, len(data_sorted) + 1) / len(data_sorted)

    # Step 4: Plot the empirical CDF
    plt.figure(figsize=(6, 6))
    plt.step(data_sorted, cdf_values, where='post', label='Empirical CDF')
    plt.title('Empirical Cumulative Distribution Function')
    # Add a y=x line
    plt.plot(data_sorted, data_sorted, label='Uniform CDF', linestyle='--')
    plt.xlabel('Data Points')
    plt.ylabel('CDF')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
def plot_ecdfs(data_list, labels, title=None):
    # Step 2: Sort the data
    sorted_data = []
    for data in data_list:
        data_sorted = np.sort(data)
        sorted_data.append(data_sorted)

    # Step 3: Calculate the empirical CDF
    # For each point, the CDF value is the proportion of data points less than or equal to that point
    cdf_values = np.arange(1, len(data_sorted) + 1) / len(data_sorted)

    # Step 4: Plot the empirical CDF
    plt.figure(figsize=(6, 6))
    for i, data in enumerate(sorted_data):
        plt.step(data, cdf_values, where='post', 
                 label=labels[i])
    if not title:
        plt.title('Empirical Cumulative Distribution Function')
    else:
        plt.title(title)
    # Add a y=x line
    plt.plot(data_sorted, data_sorted, label='Uniform CDF', linestyle='--')
    plt.xlabel('Data Points')
    plt.ylabel('CDF')
    plt.grid(True)
    plt.legend()
    plt.show()

# %% [markdown]
# # Y_sd = 3, omega_sd = 0.5

# %%
#base_dir = 'root/n50_y1_o2/'
#base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o1/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o0.5/'
dir_list = [base_dir + "root_inferencen50p5y3o0.5_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 98., 100.,  91., 112., 106., 104., 113., 100.,  81.,  95.]),
#  array([6.45061533e-04, 1.00559659e-01, 2.00474256e-01, 3.00388853e-01,
#         4.00303450e-01, 5.00218048e-01, 6.00132645e-01, 7.00047242e-01,
#         7.99961839e-01, 8.99876436e-01, 9.99791034e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([449., 137.,  84.,  51.,  38.,  12.,   8.,   4.,  11., 206.]),
#  array([6.74757507e-07, 9.99985314e-02, 1.99996388e-01, 2.99994245e-01,
#         3.99992101e-01, 4.99989958e-01, 5.99987815e-01, 6.99985671e-01,
#         7.99983528e-01, 8.99981385e-01, 9.99979241e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"],
           title="$sd(y)=3$, $sd(\omega) = 0.5$")

# %% [markdown]
# # Y_sd = 3, omega_sd = 1

# %%
#base_dir = 'root/n50_y1_o2/'
#base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o1/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o1/'
dir_list = [base_dir + "root_inferencen50p5y3o1.0_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 66., 101.,  78., 114.,  91., 124., 142., 100.,  95.,  89.]),
#  array([0.00346594, 0.10310499, 0.20274405, 0.3023831 , 0.40202215,
#         0.5016612 , 0.60130025, 0.7009393 , 0.80057835, 0.90021741,
#         0.99985646]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([406., 163.,  96.,  53.,  27.,  16.,   9.,   3.,  11., 216.]),
#  array([3.64708755e-06, 9.99965107e-02, 1.99989374e-01, 2.99982238e-01,
#         3.99975102e-01, 4.99967965e-01, 5.99960829e-01, 6.99953692e-01,
#         7.99946556e-01, 8.99939420e-01, 9.99932283e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"],
           title="$sd(y)=3$, $sd(\omega) = 1$")

# %% [markdown]
# # Y_sd = 3, omega_sd = 2

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o2/'
dir_list = [base_dir + "root_inferencen50p5y3o2_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 89.,  87., 102.,  96., 110., 127., 116.,  99.,  90.,  84.]),
#  array([2.40266993e-04, 9.99936241e-02, 1.99746981e-01, 2.99500338e-01,
#         3.99253695e-01, 4.99007053e-01, 5.98760410e-01, 6.98513767e-01,
#         7.98267124e-01, 8.98020481e-01, 9.97773838e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([411., 158.,  90.,  64.,  33.,  14.,   7.,   4.,   4., 215.]),
#  array([7.19408238e-08, 1.00000039e-01, 2.00000006e-01, 2.99999974e-01,
#         3.99999941e-01, 4.99999908e-01, 5.99999875e-01, 6.99999842e-01,
#         7.99999810e-01, 8.99999777e-01, 9.99999744e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"],
           title="$sd(y)=3$, $sd(\omega) = 2$")

# %% [markdown]
# # Y_sd = 3, omega_sd = 3

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o3/'
dir_list = [base_dir + "root_inferencen50p5y3o3_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 64.,  75.,  92., 131., 130., 116., 101., 104.,  93.,  94.]),
#  array([2.53173446e-04, 1.00135091e-01, 2.00017008e-01, 2.99898926e-01,
#         3.99780843e-01, 4.99662761e-01, 5.99544678e-01, 6.99426596e-01,
#         7.99308513e-01, 8.99190431e-01, 9.99072348e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([417., 158.,  94.,  66.,  29.,  28.,   5.,   4.,  11., 188.]),
#  array([7.48711775e-06, 1.00005840e-01, 2.00004192e-01, 3.00002544e-01,
#         4.00000897e-01, 4.99999249e-01, 5.99997602e-01, 6.99995954e-01,
#         7.99994307e-01, 8.99992659e-01, 9.99991011e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"],
           title="$sd(y)=3$, $sd(\omega) = 3$")

# %% [markdown]
# # Y_sd = 3, omega_sd = 4

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y3o4/'
dir_list = [base_dir + "root_inferencen50p5y3o4_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 73.,  92., 101., 105., 122., 129., 106.,  96.,  87.,  89.]),
#  array([3.29982374e-04, 1.00291984e-01, 2.00253986e-01, 3.00215988e-01,
#         4.00177990e-01, 5.00139992e-01, 6.00101994e-01, 7.00063995e-01,
#         8.00025997e-01, 8.99987999e-01, 9.99950001e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([403., 142.,  94.,  56.,  42.,  23.,  15.,   8.,   8., 209.]),
#  array([1.59433719e-05, 1.00014105e-01, 2.00012266e-01, 3.00010427e-01,
#         4.00008588e-01, 5.00006749e-01, 6.00004910e-01, 7.00003071e-01,
#         8.00001232e-01, 8.99999394e-01, 9.99997555e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"],
           title="$sd(y)=3$, $sd(\omega) = 4$")

# %% [markdown]
# ## Y_sd = 1, omega_sd = 1

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y1o1/'
dir_list = [base_dir + "root_inferencen50p5y1o1_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 22.,  78., 105., 113., 126., 157., 129., 117.,  90.,  63.]),
#  array([0.00225175, 0.1015137 , 0.20077566, 0.30003762, 0.39929957,
#         0.49856153, 0.59782349, 0.69708544, 0.7963474 , 0.89560936,
#         0.99487131]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([166., 125., 113., 119., 104.,  99.,  78.,  81.,  60.,  55.]),
#  array([4.02195268e-05, 9.98031584e-02, 1.99566097e-01, 2.99329036e-01,
#         3.99091975e-01, 4.98854914e-01, 5.98617853e-01, 6.98380792e-01,
#         7.98143731e-01, 8.97906670e-01, 9.97669609e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])

# %% [markdown]
# ## Y_sd = 1, omega_sd = 1, finer grid

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y1o1_g500/'
dir_list = [base_dir + "root_inferencen50p5y1o1_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 26.,  71., 103., 132., 141., 134., 158., 108.,  84.,  43.]),
#  array([8.80079327e-04, 1.00787498e-01, 2.00694917e-01, 3.00602336e-01,
#         4.00509754e-01, 5.00417173e-01, 6.00324592e-01, 7.00232011e-01,
#         8.00139429e-01, 9.00046848e-01, 9.99954267e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([166., 124., 130., 120.,  85.,  79.,  88.,  83.,  78.,  47.]),
#  array([2.33952861e-04, 1.00001797e-01, 1.99769640e-01, 2.99537484e-01,
#         3.99305328e-01, 4.99073172e-01, 5.98841015e-01, 6.98608859e-01,
#         7.98376703e-01, 8.98144547e-01, 9.97912390e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])

# %% [markdown]
# ## Y_sd = 5, omega_sd = 1

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y5o1/'
dir_list = [base_dir + "root_inferencen50p5y5o1_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([261.,  79.,  50.,  33.,  46.,  48.,  50.,  65.,  75., 293.]),
#  array([4.96717456e-12, 1.00000000e-01, 2.00000000e-01, 3.00000000e-01,
#         4.00000000e-01, 5.00000000e-01, 6.00000000e-01, 7.00000000e-01,
#         8.00000000e-01, 9.00000000e-01, 1.00000000e+00]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([490., 102.,  33.,  13.,   2.,   1.,   0.,   1.,  10., 348.]),
#  array([1.33402747e-06, 9.99984639e-02, 1.99995594e-01, 2.99992724e-01,
#         3.99989854e-01, 4.99986984e-01, 5.99984114e-01, 6.99981243e-01,
#         7.99978373e-01, 8.99975503e-01, 9.99972633e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])

# %% [markdown]
# ## Y_sd = 5, omega_sd = 1, finer grid

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y5o1_g500/'
dir_list = [base_dir + "root_inferencen50p5y5o1_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([ 95., 103.,  95., 100.,  91., 111.,  96.,  93.,  98., 118.]),
#  array([4.40407324e-04, 1.00369179e-01, 2.00297951e-01, 3.00226723e-01,
#         4.00155495e-01, 5.00084267e-01, 6.00013039e-01, 6.99941811e-01,
#         7.99870583e-01, 8.99799355e-01, 9.99728127e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([529.,  88.,  27.,  10.,   0.,   0.,   0.,   0.,   9., 337.]),
#  array([1.37392571e-06, 9.99979630e-02, 1.99994552e-01, 2.99991141e-01,
#         3.99987730e-01, 4.99984319e-01, 5.99980908e-01, 6.99977497e-01,
#         7.99974086e-01, 8.99970675e-01, 9.99967264e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])

# %% [markdown]
# ## Y_sd = 2, omega_sd = 2

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y2o2/'
dir_list = [base_dir + "root_inferencen50p5y2o2_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([218., 161., 128., 113.,  97.,  74.,  62.,  45.,  29.,  73.]),
#  array([7.79599443e-06, 9.99882419e-02, 1.99968688e-01, 2.99949134e-01,
#         3.99929580e-01, 4.99910025e-01, 5.99890471e-01, 6.99870917e-01,
#         7.99851363e-01, 8.99831809e-01, 9.99812255e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([272., 149., 128.,  93.,  89.,  62.,  51.,  36.,  27.,  93.]),
#  array([8.09201791e-06, 1.00006869e-01, 2.00005646e-01, 3.00004422e-01,
#         4.00003199e-01, 5.00001976e-01, 6.00000753e-01, 6.99999530e-01,
#         7.99998307e-01, 8.99997083e-01, 9.99995860e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])

# %% [markdown]
# ## Y_sd = 2, omega_sd = 2, finer grid

# %%
#base_dir = 'root/n50_y1_o2/'
base_dir = '/Users/yilingh/Desktop/PhD/Selective Inference/SI_Trees/Simulation/y2o2_g500/'
dir_list = [base_dir + "root_inferencen50p5y2o2_" + str(i*100) + "_" + str(i*100 + 100) + ".pkl" for i in range(10)]

# %%
pivots = []
naive_pivots = []
for d in dir_list:
    ps, nps = (joblib.load(d))
    pivots += ps
    naive_pivots += nps

# %%
len(naive_pivots)
# Out:
# 1000

# %%
plt.hist(pivots)
# Out:
# (array([217., 169., 144., 113.,  86.,  80.,  51.,  41.,  28.,  71.]),
#  array([1.44454914e-04, 1.00120089e-01, 2.00095723e-01, 3.00071357e-01,
#         4.00046991e-01, 5.00022626e-01, 5.99998260e-01, 6.99973894e-01,
#         7.99949528e-01, 8.99925162e-01, 9.99900796e-01]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(naive_pivots)
# Out:
# (array([255., 168., 133., 114.,  75.,  63.,  40.,  44.,  24.,  84.]),
#  array([6.10739766e-05, 1.00054322e-01, 2.00047569e-01, 3.00040817e-01,
#         4.00034065e-01, 5.00027312e-01, 6.00020560e-01, 7.00013808e-01,
#         8.00007055e-01, 9.00000303e-01, 9.99993551e-01]),
#  <BarContainer object of 10 artists>)

# %%
plot_ecdfs([pivots, naive_pivots], ["Selective CDF", "Naive CDF"])
